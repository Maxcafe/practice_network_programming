# %%
from scapy.all import *

# %%
packets = rdpcap('./Tello_接続から離陸まで.pcap')
packets_a = rdpcap('./a.pcap')

# %%
# list_packets_src_ipad = []
# for i, packet in enumerate(packets, 1):
#     if (packet.src == '192.168.10.2') and (packet.dst == '192.168.10.1'):
#         print(len(packet))
#         print(ls(packet))
#         list_packets_src_ipad.append(packet)
# #         send(packet)
# Out:
# 64
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 64              (None)
# id         : ShortField                          = 0               (1)
# flags      : FlagsField (3 bits)                 = <Flag 2 (DF)>   (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 6               (0)
# chksum     : XShortField                         = 42340           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 49215           (20)
# dport      : ShortEnumField                      = 9999            (80)
# seq        : IntField                            = 97121746        (0)
# ack        : IntField                            = 0               (0)
# dataofs    : BitField (4 bits)                   = 11              (None)
# reserved   : BitField (3 bits)                   = 0               (0)
# flags      : FlagsField (9 bits)                 = <Flag 194 (SEC)> (<Flag 2 (S)>)
# window     : ShortField                          = 65535           (8192)
# chksum     : XShortField                         = 38278           (None)
# urgptr     : ShortField                          = 0               (0)
# options    : TCPOptionsField                     = [('MSS', 1460), ('NOP', None), ('WScale', 6), ('NOP', None), ('NOP', None), ('Timestamp', (762421530, 0)), ('SAckOK', b''), ('EOL', None)] (b'')
# None
# 40
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 40              (None)
# id         : ShortField                          = 0               (1)
# flags      : FlagsField (3 bits)                 = <Flag 2 (DF)>   (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 6               (0)
# chksum     : XShortField                         = 42364           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 49215           (20)
# dport      : ShortEnumField                      = 9999            (80)
# seq        : IntField                            = 97121747        (0)
# ack        : IntField                            = 6511            (0)
# dataofs    : BitField (4 bits)                   = 5               (None)
# reserved   : BitField (3 bits)                   = 0               (0)
# flags      : FlagsField (9 bits)                 = <Flag 16 (A)>   (<Flag 2 (S)>)
# window     : ShortField                          = 65535           (8192)
# chksum     : XShortField                         = 38254           (None)
# urgptr     : ShortField                          = 0               (0)
# options    : TCPOptionsField                     = []              (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 26735           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 31992           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06\xd2\x01<,' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 22843           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 35884           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06\xde\x01\x9c\x85' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 63647           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 60615           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06\xe5\x01\x96\xd7' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 40565           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 18162           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06\xf8\x01\x7f\xf2' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 13753           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 44974           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06\r\x02T\xc2' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 39854           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 18873           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06\'\x02\x17\x1c' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 62610           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 61652           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x065\x026\xba' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 19255           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 39472           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06I\x02R\xe3' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 22125           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 36602           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06`\x02y\x17' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 13270           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 45457           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06q\x020\x9b' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 6864            (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 51863           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06\x85\x02X\x80' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 55811           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 2916            (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06\x99\x02i\xbc' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 64770           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 59492           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06\xad\x02\xabm' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 14303           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 44424           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06\xc1\x02^\xa1' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 3153            (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 55574           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06\xd5\x02\xafS' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 21361           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 37366           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06\xe9\x02\xadL' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 64211           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 60051           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06\xfd\x02\\\xbe' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 54946           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 3781            (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06\x11\x03\xec\xef' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 15154           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 43573           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06%\x03.>' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 62892           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 61370           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x069\x03\x1f\x02' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 54727           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 4000            (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06M\x03\xbb\x95' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 31099           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 27628           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06a\x03(\x1f' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 6010            (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 52717           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06u\x03\xd9\xed' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 44296           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 14431           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06\x89\x03q8' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 16774           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 41953           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06\x9d\x03\x80\xca' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 35831           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 22896           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06\xb1\x03\x13@' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 50956           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 7771            (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06\xc5\x03\xb7\xd7' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 56520           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 2207            (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x06\xd9\x03\x86\xeb' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 620             (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 58107           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x07\x05\x00Zu' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 48036           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 10691           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x07\x19\x00kI' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 24254           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 34473           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\x07-\x00\xa9\x98' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 57681           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 1046            (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# ...
# chksum     : XShortField                         = 38463           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 26              (None)
# chksum     : XShortField                         = 38271           (None)
# --
# load       : StrField                            = b'\xcc\x90\x00\xbepR\x10\x80\x02\x00\x16yZ\x00\x00\x00\xed\xfc' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 33577           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 25150           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\rm\x01<\xbc' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 46001           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 12726           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\r\x81\x01\x05\xfc' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 64781           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 59481           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\r\x95\x01\xf4\x0e' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 17819           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 40908           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\r\xa9\x01\xf6\x11' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 64775           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 59487           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\r\xbd\x01\x07\xe3' (b'')
# None
# 46
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 46              (None)
# id         : ShortField                          = 29309           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 29422           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 26              (None)
# chksum     : XShortField                         = 38271           (None)
# --
# load       : StrField                            = b'\xcc\x90\x00\xbepR\x10\x84\x02\x00by[\x00\x00\x00\x1e\n' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 32600           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 26127           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\r\xd1\x01\xf2/' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 58508           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 219             (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\r\xe5\x010\xfe' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 23862           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 34865           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\r\xf9\x01\x01\xc2' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 33798           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 24929           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\r\r\x02\xf2\xeb' (b'')
# None
# 50
# version    : BitField (4 bits)                   = 4               (4)
# ihl        : BitField (4 bits)                   = 5               (None)
# tos        : XByteField                          = 0               (0)
# len        : ShortField                          = 50              (None)
# id         : ShortField                          = 48369           (1)
# flags      : FlagsField (3 bits)                 = <Flag 0 ()>     (<Flag 0 ()>)
# frag       : BitField (13 bits)                  = 0               (0)
# ttl        : ByteField                           = 64              (64)
# proto      : ByteEnumField                       = 17              (0)
# chksum     : XShortField                         = 10358           (None)
# src        : SourceIPField                       = '192.168.10.2'  (None)
# dst        : DestIPField                         = '192.168.10.1'  (None)
# options    : PacketListField                     = []              ([])
# --
# sport      : ShortEnumField                      = 7777            (53)
# dport      : ShortEnumField                      = 8889            (53)
# len        : ShortField                          = 30              (None)
# chksum     : XShortField                         = 38275           (None)
# --
# load       : StrField                            = b'\xcc\xb0\x00\x7f`P\x00\x00\x00\x00\x04 \x00\x01\x08\x16"\r!\x02aa' (b'')
# None

# %%
for i, packet in enumerate(packets, 1):
    print(packet[Ether].show)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-66ac7449e25b> in <module>
#       1 for i, packet in enumerate(packets, 1):
# ----> 2     print(packet[Ether].show)
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/scapy/packet.py in __getitem__(self, cls)
#    1169             elif not isinstance(lname, bytes):
#    1170                 lname = repr(lname)
# -> 1171             raise IndexError("Layer [%s] not found" % lname)
#    1172         return ret
#    1173
#
# IndexError: Layer [Ether] not found

# %%
# for i, pakcet in enumerate(list_packets_src_ipad, 1):
#     if i % 50 == 0:
#         print('%d / %d' % (i, len(list_packets_src_ipad)))
#     send(pakcet, iface='en0')
# print('finish!')

# %%
# lsc()
